# %%
import pandas as pd
import numpy as np
import re
import string
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize

# Download NLTK resources (run once)
try:
    nltk.data.find('tokenizers/punkt')
except LookupError:
    nltk.download('punkt', quiet=True)

try:
    nltk.data.find('corpora/stopwords')
except LookupError:
    nltk.download('stopwords', quiet=True)

# Enhanced text preprocessing function
def preprocess_text(text):
    if not isinstance(text, str):
        return ""
    
    # Convert to lowercase
    text = text.lower()
    
    # Remove numbers
    text = re.sub(r'\d+', '', text)
    
    # Remove punctuation
    text = text.translate(str.maketrans('', '', string.punctuation))
    
    # Remove whitespaces
    text = text.strip()
    
    # Tokenization
    tokens = word_tokenize(text)
    
    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    tokens = [token for token in tokens if token not in stop_words]
    
    # Stemming
    stemmer = PorterStemmer()
    tokens = [stemmer.stem(token) for token in tokens]
    
    return ' '.join(tokens)

# Function to detect spam in a file
def detect_spam_in_file(file_path, model=None, vectorizer=None):
    """
    Detect spam messages in a file using a trained model
    
    Parameters:
    file_path (str): Path to the file containing messages
    model: Trained model for prediction (if None, will train one)
    vectorizer: Fitted vectorizer (if None, will create one)
    
    Returns:
    DataFrame: Original messages with spam predictions
    """
    # Read the file
    try:
        # Try different formats
        try:
            # Try CSV format with header
            df = pd.read_csv(file_path)
            if 'message' not in df.columns and 'text' not in df.columns:
                # If no obvious message column, use the first column
                df.columns = ['message'] + list(df.columns[1:])
        except:
            # Try tab-separated without header
            df = pd.read_csv(file_path, sep='\t', header=None)
            if len(df.columns) >= 2:
                # Assume first column is label, second is message
                df.columns = ['label', 'message'] + [f'col{i}' for i in range(2, len(df.columns))]
            else:
                # Assume only message column
                df.columns = ['message']
    except Exception as e:
        print(f"Error reading file: {e}")
        return None
    
    # Check if we have a message column
    if 'message' not in df.columns:
        print("No 'message' column found in the file")
        return None
    
    # Check if we need to train a model
    if model is None or vectorizer is None:
        print("Training a new model...")
        model, vectorizer = train_spam_detector()
    
    # Preprocess messages
    df['cleaned_message'] = df['message'].apply(preprocess_text)
    
    # Transform messages
    X = vectorizer.transform(df['cleaned_message'])
    
    # Make predictions
    predictions = model.predict(X)
    probabilities = model.predict_proba(X)
    
    # Add predictions to dataframe
    df['is_spam'] = predictions
    df['spam_probability'] = probabilities[:, 1]  # Probability of being spam
    df['prediction'] = df['is_spam'].apply(lambda x: 'spam' if x == 1 else 'ham')
    
    return df

# Function to train a spam detector
def train_spam_detector():
    """
    Train a spam detection model
    
    Returns:
    tuple: (trained_model, fitted_vectorizer)
    """
    # Load the training data
    features = ['label', 'message']
    try:
        sms = pd.read_csv('sms.txt', header=None, names=features, sep='\t')
    except FileNotFoundError:
        print("Training file 'sms.txt' not found. Please make sure it exists.")
        return None, None
    
    # Convert label to numerical variable
    sms['label_num'] = sms.label.map({'ham': 0, 'spam': 1})
    
    # Apply text preprocessing
    sms['cleaned_message'] = sms['message'].apply(preprocess_text)
    
    # Prepare features and target
    X = sms.cleaned_message
    y = sms.label_num
    
    # Create and fit vectorizer
    vectorizer = TfidfVectorizer(ngram_range=(1, 2), max_df=0.5, min_df=2)
    X_vectorized = vectorizer.fit_transform(X)
    
    # Split the data
    X_train, X_test, y_train, y_test = train_test_split(
        X_vectorized, y, test_size=0.2, random_state=42, stratify=y
    )
    
    # Train model
    model = MultinomialNB()
    model.fit(X_train, y_train)
    
    # Evaluate model
    y_pred = model.predict(X_test)
    accuracy = metrics.accuracy_score(y_test, y_pred)
    print(f"Model trained with accuracy: {accuracy:.4f}")
    
    return model, vectorizer

# Function to save results
def save_results(df, output_file):
    """
    Save detection results to a file
    
    Parameters:
    df (DataFrame): Results dataframe
    output_file (str): Path to output file
    """
    # Select only relevant columns
    if 'label' in df.columns:
        result_df = df[['label', 'message', 'prediction', 'spam_probability']]
    else:
        result_df = df[['message', 'prediction', 'spam_probability']]
    
    # Save to CSV
    result_df.to_csv(output_file, index=False)
    print(f"Results saved to {output_file}")
    
    # Print summary
    spam_count = (result_df['prediction'] == 'spam').sum()
    total_count = len(result_df)
    print(f"Found {spam_count} spam messages out of {total_count} total messages")
    print(f"Spam rate: {spam_count/total_count*100:.2f}%")

# Function to display results
def display_results(df):
    """
    Display detection results
    
    Parameters:
    df (DataFrame): Results dataframe
    """
    # Print spam messages
    spam_df = df[df['prediction'] == 'spam']
    if len(spam_df) > 0:
        print("\n=== SPAM MESSAGES DETECTED ===")
        for i, row in spam_df.iterrows():
            print(f"\nMessage: {row['message']}")
            print(f"Spam probability: {row['spam_probability']:.4f}")
            if 'label' in row and pd.notna(row['label']):
                print(f"Actual label: {row['label']}")
    
    # Print summary
    spam_count = (df['prediction'] == 'spam').sum()
    total_count = len(df)
    print(f"\n=== SUMMARY ===")
    print(f"Total messages: {total_count}")
    print(f"Spam messages: {spam_count}")
    print(f"Ham messages: {total_count - spam_count}")
    print(f"Spam rate: {spam_count/total_count*100:.2f}%")

# Main execution
if __name__ == "__main__":
    # Train or load model
    model, vectorizer = train_spam_detector()
    
    if model is not None:
        # Ask user for file path
        file_path = input("Enter the path to your SMS file (or press Enter to use default 'sms.txt'): ").strip()
        if not file_path:
            file_path = "sms.txt"
        
        # Detect spam in file
        results = detect_spam_in_file(file_path, model, vectorizer)
        
        if results is not None:
            # Display results
            display_results(results)
            
            # Ask if user wants to save results
            save_option = input("\nDo you want to save the results to a file? (y/n): ").strip().lower()
            if save_option == 'y':
                output_file = input("Enter output file name (default: spam_results.csv): ").strip()
                if not output_file:
                    output_file = "spam_results.csv"
                save_results(results, output_file)
# Out:
# Model trained with accuracy: 0.9659
#
# === SPAM MESSAGES DETECTED ===
#
# Message: Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive entry question(std txt rate)T&C's apply 08452810075over18's
# Spam probability: 0.9517
# Actual label: spam
#
# Message: WINNER!! As a valued network customer you have been selected to receivea £900 prize reward! To claim call 09061701461. Claim code KL341. Valid 12 hours only.
# Spam probability: 0.9880
# Actual label: spam
#
# Message: Had your mobile 11 months or more? U R entitled to Update to the latest colour mobiles with camera for Free! Call The Mobile Update Co FREE on 08002986030
# Spam probability: 0.9037
# Actual label: spam
#
# Message: SIX chances to win CASH! From 100 to 20,000 pounds txt> CSH11 and send to 87575. Cost 150p/day, 6days, 16+ TsandCs apply Reply HL 4 info
# Spam probability: 0.9688
# Actual label: spam
#
# Message: URGENT! You have won a 1 week FREE membership in our £100,000 Prize Jackpot! Txt the word: CLAIM to No: 81010 T&C www.dbuk.net LCCLTD POBOX 4403LDNW1A7RW18
# Spam probability: 0.9611
# Actual label: spam
#
# Message: England v Macedonia - dont miss the goals/team news. Txt ur national team to 87077 eg ENGLAND to 87077 Try:WALES, SCOTLAND 4txt/ú1.20 POBOXox36504W45WQ 16+
# Spam probability: 0.5517
# Actual label: spam
#
# Message: Thanks for your subscription to Ringtone UK your mobile will be charged £5/month Please confirm by replying YES or NO. If you reply NO you will not be charged
# Spam probability: 0.7147
# Actual label: spam
#
# Message: 07732584351 - Rodger Burns - MSG = We tried to call you re your reply to our sms for a free nokia mobile + free camcorder. Please call now 08000930705 for delivery tomorrow
# Spam probability: 0.9349
# Actual label: spam
#
# Message: Congrats! 1 year special cinema pass for 2 is yours. call 09061209465 now! C Suprman V, Matrix3, StarWars3, etc all 4 FREE! bx420-ip4-5we. 150pm. Dont miss out!
# Spam probability: 0.8254
# Actual label: spam
#
# Message: As a valued customer, I am pleased to advise you that following recent review of your Mob No. you are awarded with a £1500 Bonus Prize, call 09066364589
# Spam probability: 0.9521
# Actual label: spam
#
# Message: Urgent UR awarded a complimentary trip to EuroDisinc Trav, Aco&Entry41 Or £1000. To claim txt DIS to 87121 18+6*£1.50(moreFrmMob. ShrAcomOrSglSuplt)10, LS1 3AJ
# Spam probability: 0.9610
# Actual label: spam
#
# Message: Please call our customer service representative on 0800 169 6031 between 10am-9pm as you have WON a guaranteed £1000 cash or £5000 prize!
# Spam probability: 0.9925
# Actual label: spam
#
# Message: Your free ringtone is waiting to be collected. Simply text the password "MIX" to 85069 to verify. Get Usher and Britney. FML, PO Box 5249, MK17 92H. 450Ppw 16
# Spam probability: 0.9493
# Actual label: spam
#
# Message: GENT! We are trying to contact you. Last weekends draw shows that you won a £1000 prize GUARANTEED. Call 09064012160. Claim Code K52. Valid 12hrs only. 150ppm
# Spam probability: 0.9953
# Actual label: spam
#
# Message: You are a winner U have been specially selected 2 receive £1000 or a 4* holiday (flights inc) speak to a live operator 2 claim 0871277810910p/min (18+)
# Spam probability: 0.9850
# Actual label: spam
#
# Message: PRIVATE! Your 2004 Account Statement for 07742676969 shows 786 unredeemed Bonus Points. To claim call 08719180248 Identifier Code: 45239 Expires
# Spam probability: 0.9966
# Actual label: spam
#
# Message: URGENT! Your Mobile No. was awarded £2000 Bonus Caller Prize on 5/9/03 This is our final try to contact U! Call from Landline 09064019788 BOX42WR29C, 150PPM
# Spam probability: 0.9938
# Actual label: spam
#
# Message: Todays Voda numbers ending 7548 are selected to receive a $350 award. If you have a match please call 08712300220 quoting claim code 4041 standard rates app
# Spam probability: 0.9878
# Actual label: spam
#
# Message: Sunshine Quiz Wkly Q! Win a top Sony DVD player if u know which country the Algarve is in? Txt ansr to 82277. £1.50 SP:Tyrone
# Spam probability: 0.9661
# Actual label: spam
#
# Message: Want 2 get laid tonight? Want real Dogging locations sent direct 2 ur mob? Join the UK's largest Dogging Network bt Txting GRAVEL to 69888! Nt. ec2a. 31p.msg@150p
# Spam probability: 0.8138
# Actual label: spam
#
# Message: FreeMsg Why haven't you replied to my text? I'm Randy, sexy, female and live local. Luv to hear from u. Netcollex Ltd 08700621170150p per msg reply Stop to end
# Spam probability: 0.8132
# Actual label: spam
#
# Message: Customer service annoncement. You have a New Years delivery waiting for you. Please call 07046744435 now to arrange delivery
# Spam probability: 0.5538
# Actual label: spam
#
# Message: You are a winner U have been specially selected 2 receive £1000 cash or a 4* holiday (flights inc) speak to a live operator 2 claim 0871277810810
# Spam probability: 0.9861
# Actual label: spam
#
# Message: -PLS STOP bootydelious (32/F) is inviting you to be her friend. Reply YES-434 or NO-434 See her: www.SMS.ac/u/bootydelious STOP? Send STOP FRND to 62468
# Spam probability: 0.6129
# Actual label: spam
#
# Message: BangBabes Ur order is on the way. U SHOULD receive a Service Msg 2 download UR content. If U do not, GoTo wap. bangb. tv on UR mobile internet/service menu
# Spam probability: 0.6316
# Actual label: spam
#
# Message: URGENT! We are trying to contact you. Last weekends draw shows that you have won a £900 prize GUARANTEED. Call 09061701939. Claim code S89. Valid 12hrs only
# Spam probability: 0.9960
# Actual label: spam
#
# Message: Please call our customer service representative on FREEPHONE 0808 145 4742 between 9am-11pm as you have WON a guaranteed £1000 cash or £5000 prize!
# Spam probability: 0.9939
# Actual label: spam
#
# Message: 500 New Mobiles from 2004, MUST GO! Txt: NOKIA to No: 89545 & collect yours today!From ONLY £1 www.4-tc.biz 2optout 087187262701.50gbp/mtmsg18
# Spam probability: 0.9375
# Actual label: spam
#
# Message: U 447801259231 have a secret admirer who is looking 2 make contact with U-find out who they R*reveal who thinks UR so special-call on 09058094597
# Spam probability: 0.8921
# Actual label: spam
#
# Message: Congratulations ur awarded 500 of CD vouchers or 125gift guaranteed & Free entry 2 100 wkly draw txt MUSIC to 87066 TnCs www.Ldew.com1win150ppmx3age16
# Spam probability: 0.9945
# Actual label: spam
#
# Message: We tried to contact you re your reply to our offer of a Video Handset? 750 anytime networks mins? UNLIMITED TEXT? Camcorder? Reply or call 08000930705 NOW
# Spam probability: 0.9698
# Actual label: spam
#
# Message: Ur ringtone service has changed! 25 Free credits! Go to club4mobiles.com to choose content now! Stop? txt CLUB STOP to 87070. 150p/wk Club4 PO Box1146 MK45 2WT
# Spam probability: 0.9557
# Actual label: spam
#
# Message: Ringtone Club: Get the UK singles chart on your mobile each week and choose any top quality ringtone! This message is free of charge.
# Spam probability: 0.8801
# Actual label: spam
#
# Message: HMV BONUS SPECIAL 500 pounds of genuine HMV vouchers to be won. Just answer 4 easy questions. Play Now! Send HMV to 86688 More info:www.100percent-real.com
# Spam probability: 0.9214
# Actual label: spam
#
# Message: T-Mobile customer you may now claim your FREE CAMERA PHONE upgrade & a pay & go sim card for your loyalty. Call on 0845 021 3680.Offer ends 28thFeb.T&C's apply
# Spam probability: 0.8548
# Actual label: spam
#
# Message: TheMob> Check out our newest selection of content, Games, Tones, Gossip, babes and sport, Keep your mobile fit and funky text WAP to 82468
# Spam probability: 0.6973
# Actual label: spam
#
# Message: Think ur smart ? Win £200 this week in our weekly quiz, text PLAY to 85222 now!T&Cs WinnersClub PO BOX 84, M26 3UZ. 16+. GBP1.50/week
# Spam probability: 0.8247
# Actual label: spam
#
# Message: December only! Had your mobile 11mths+? You are entitled to update to the latest colour camera mobile for Free! Call The Mobile Update Co FREE on 08002986906
# Spam probability: 0.9448
# Actual label: spam
#
# Message: Call Germany for only 1 pence per minute! Call from a fixed line via access number 0844 861 85 85. No prepayment. Direct access!
# Spam probability: 0.7840
# Actual label: spam
#
# Message: Valentines Day Special! Win over £1000 in our quiz and take your partner on the trip of a lifetime! Send GO to 83600 now. 150p/msg rcvd. CustCare:08718720201.
# Spam probability: 0.8202
# Actual label: spam
#
# Message: Fancy a shag? I do.Interested? sextextuk.com txt XXUK SUZY to 69876. Txts cost 1.50 per msg. TnCs on website. X
# Spam probability: 0.8002
# Actual label: spam
#
# Message: Congratulations ur awarded 500 of CD vouchers or 125gift guaranteed & Free entry 2 100 wkly draw txt MUSIC to 87066 TnCs www.Ldew.com1win150ppmx3age16
# Spam probability: 0.9945
# Actual label: spam
#
# Message: Ur cash-balance is currently 500 pounds - to maximize ur cash-in now send CASH to 86688 only 150p/msg. CC: 08708800282 HG/Suite342/2Lands Row/W1J6HL
# Spam probability: 0.9749
# Actual label: spam
#
# Message: Update_Now - Xmas Offer! Latest Motorola, SonyEricsson & Nokia & FREE Bluetooth! Double Mins & 1000 Txt on Orange. Call MobileUpd8 on 08000839402 or call2optout/F4Q=
# Spam probability: 0.9787
# Actual label: spam
#
# Message: Here is your discount code RP176781. To stop further messages reply stop. www.regalportfolio.co.uk. Customer Services 08717205546
# Spam probability: 0.9175
# Actual label: spam
#
# Message: Thanks for your Ringtone Order, Reference T91. You will be charged GBP 4 per week. You can unsubscribe at anytime by calling customer services on 09057039994
# Spam probability: 0.9631
# Actual label: spam
#
# Message: Double mins and txts 4 6months FREE Bluetooth on Orange. Available on Sony, Nokia Motorola phones. Call MobileUpd8 on 08000839402 or call2optout/N9DX
# Spam probability: 0.9426
# Actual label: spam
#
# Message: 4mths half price Orange line rental & latest camera phones 4 FREE. Had your phone 11mths ? Call MobilesDirect free on 08000938767 to update now! or2stoptxt
# Spam probability: 0.9711
# Actual label: spam
#
# Message: FREE RINGTONE text FIRST to 87131 for a poly or text GET to 87131 for a true tone! Help? 0845 2814032 16 after 1st free, tones are 3x£150pw to e£nd txt stop
# Spam probability: 0.9029
# Actual label: spam
#
# Message: 100 dating service cal;l 09064012103 box334sk38ch
# Spam probability: 0.8022
# Actual label: spam
#
# Message: FREE entry into our £250 weekly competition just text the word WIN to 80086 NOW. 18 T&C www.txttowin.co.uk
# Spam probability: 0.9069
# Actual label: spam
#
# Message: Send a logo 2 ur lover - 2 names joined by a heart. Txt LOVE NAME1 NAME2 MOBNO eg LOVE ADAM EVE 07123456789 to 87077 Yahoo! POBox36504W45WQ TxtNO 4 no ads 150p
# Spam probability: 0.7805
# Actual label: spam
#
# Message: Someone has contacted our dating service and entered your phone because they fancy you! To find out who it is call from a landline 09111032124 . PoBox12n146tf150p
# Spam probability: 0.9532
# Actual label: spam
#
# Message: URGENT! Your Mobile number has been awarded with a £2000 prize GUARANTEED. Call 09058094455 from land line. Claim 3030. Valid 12hrs only
# Spam probability: 0.9975
# Actual label: spam
#
# Message: Congrats! Nokia 3650 video camera phone is your Call 09066382422 Calls cost 150ppm Ave call 3mins vary from mobiles 16+ Close 300603 post BCM4284 Ldn WC1N3XX
# Spam probability: 0.9444
# Actual label: spam
#
# Message: Loan for any purpose £500 - £75,000. Homeowners + Tenants welcome. Have you been previously refused? We can still help. Call Free 0800 1956669 or text back 'help'
# Spam probability: 0.8616
# Actual label: spam
#
# Message: UpgrdCentre Orange customer, you may now claim your FREE CAMERA PHONE upgrade for your loyalty. Call now on 0207 153 9153. Offer ends 26th July. T&C's apply. Opt-out available
# Spam probability: 0.9572
# Actual label: spam
#
# Message: okmail: Dear Dave this is your final notice to collect your 4* Tenerife Holiday or #5000 CASH award! Call 09061743806 from landline. TCs SAE Box326 CW25WX 150ppm
# Spam probability: 0.9885
# Actual label: spam
#
# Message: Want 2 get laid tonight? Want real Dogging locations sent direct 2 ur Mob? Join the UK's largest Dogging Network by txting MOAN to 69888Nyt. ec2a. 31p.msg@150p
# Spam probability: 0.8173
# Actual label: spam
#
# Message: FREE MESSAGE Activate your 500 FREE Text Messages by replying to this message with the word FREE For terms & conditions, visit www.07781482378.com
# Spam probability: 0.8772
# Actual label: spam
#
# Message: Congrats! 1 year special cinema pass for 2 is yours. call 09061209465 now! C Suprman V, Matrix3, StarWars3, etc all 4 FREE! bx420-ip4-5we. 150pm. Dont miss out!
# Spam probability: 0.8254
# Actual label: spam
#
# Message: +123 Congratulations - in this week's competition draw u have won the £1450 prize to claim just call 09050002311 b4280703. T&Cs/stop SMS 08718727868. Over 18 only 150ppm
# Spam probability: 0.9552
# Actual label: spam
#
# Message: You are guaranteed the latest Nokia Phone, a 40GB iPod MP3 player or a £500 prize! Txt word: COLLECT to No: 83355! IBHltd LdnW15H 150p/Mtmsgrcvd18+
# Spam probability: 0.9777
# Actual label: spam
#
# Message: Boltblue tones for 150p Reply POLY# or MONO# eg POLY3 1. Cha Cha Slide 2. Yeah 3. Slow Jamz 6. Toxic 8. Come With Me or STOP 4 more tones txt MORE
# Spam probability: 0.7861
# Actual label: spam
#
# Message: Your credits have been topped up for http://www.bubbletext.com Your renewal Pin is tgxxrz
# Spam probability: 0.5631
# Actual label: spam
#
# Message: URGENT!: Your Mobile No. was awarded a £2,000 Bonus Caller Prize on 02/09/03! This is our 2nd attempt to contact YOU! Call 0871-872-9755 BOX95QU
# Spam probability: 0.9909
# Actual label: spam
#
# Message: Today's Offer! Claim ur £150 worth of discount vouchers! Text YES to 85023 now! SavaMob, member offers mobile! T Cs 08717898035. £3.00 Sub. 16 . Unsub reply X
# Spam probability: 0.9884
# Actual label: spam
#
# Message: PRIVATE! Your 2003 Account Statement for 07815296484 shows 800 un-redeemed S.I.M. points. Call 08718738001 Identifier Code 41782 Expires 18/11/04
# Spam probability: 0.9914
# Actual label: spam
#
# Message: from www.Applausestore.com MonthlySubscription@50p/msg max6/month T&CsC web age16 2stop txt stop
# Spam probability: 0.7772
# Actual label: spam
#
# Message: GENT! We are trying to contact you. Last weekends draw shows that you won a £1000 prize GUARANTEED. Call 09064012160. Claim Code K52. Valid 12hrs only. 150ppm
# Spam probability: 0.9953
# Actual label: spam
#
# Message: You have won ?1,000 cash or a ?2,000 prize! To claim, call09050000327
# Spam probability: 0.9646
# Actual label: spam
#
# Message: our mobile number has won £5000, to claim calls us back or ring the claims hot line on 09050005321.
# Spam probability: 0.7489
# Actual label: spam
#
# Message: We tried to contact you re your reply to our offer of 750 mins 150 textand a new video phone call 08002988890 now or reply for free delivery tomorrow
# Spam probability: 0.9174
# Actual label: spam
#
# Message: For ur chance to win a £250 wkly shopping spree TXT: SHOP to 80878. T's&C's www.txt-2-shop.com custcare 08715705022, 1x150p/wk
# Spam probability: 0.9467
# Actual label: spam
#
# Message: You have been specially selected to receive a 2000 pound award! Call 08712402050 BEFORE the lines close. Cost 10ppm. 16+. T&Cs apply. AG Promo
# Spam probability: 0.9824
# Actual label: spam
#
# Message: PRIVATE! Your 2003 Account Statement for 07753741225 shows 800 un-redeemed S. I. M. points. Call 08715203677 Identifier Code: 42478 Expires 24/10/04
# Spam probability: 0.9929
# Actual label: spam
#
# Message: You have an important customer service announcement. Call FREEPHONE 0800 542 0825 now!
# Spam probability: 0.9322
# Actual label: spam
#
# Message: 22 days to kick off! For Euro2004 U will be kept up to date with the latest news and results daily. To be removed send GET TXT STOP to 83222
# Spam probability: 0.8074
# Actual label: spam
#
# Message: New TEXTBUDDY Chat 2 horny guys in ur area 4 just 25p Free 2 receive Search postcode or at gaytextbuddy.com. TXT ONE name to 89693
# Spam probability: 0.7568
# Actual label: spam
#
# Message: Todays Vodafone numbers ending with 4882 are selected to a receive a £350 award. If your number matches call 09064019014 to receive your £350 award.
# Spam probability: 0.9269
# Actual label: spam
#
# Message: Dear Voucher Holder, 2 claim this weeks offer, at your PC go to http://www.e-tlp.co.uk/expressoffer Ts&Cs apply.2 stop texts txt STOP to 80062.
# Spam probability: 0.9772
# Actual label: spam
#
# Message: PRIVATE! Your 2003 Account Statement for shows 800 un-redeemed S. I. M. points. Call 08715203694 Identifier Code: 40533 Expires 31/10/04
# Spam probability: 0.9929
# Actual label: spam
#
# Message: You have won ?1,000 cash or a ?2,000 prize! To claim, call09050000327. T&C: RSTM, SW7 3SS. 150ppm
# Spam probability: 0.9793
# Actual label: spam
#
# Message: 88800 and 89034 are premium phone services call 08718711108
# Spam probability: 0.5697
# Actual label: spam
#
# Message: Get ur 1st RINGTONE FREE NOW! Reply to this msg with TONE. Gr8 TOP 20 tones to your phone every week just £1.50 per wk 2 opt out send STOP 08452810071 16
# Spam probability: 0.8695
# Actual label: spam
#
# Message: <Forwarded from 448712404000>Please CALL 08712404000 immediately as there is an urgent message waiting for you.
# Spam probability: 0.7648
# Actual label: spam
#
# Message: To review and KEEP the fantastic Nokia N-Gage game deck with Club Nokia, go 2 www.cnupdates.com/newsletter. unsubscribe from alerts reply with the word OUT
# Spam probability: 0.7035
# Actual label: spam
#
# Message: 4mths half price Orange line rental & latest camera phones 4 FREE. Had your phone 11mths+? Call MobilesDirect free on 08000938767 to update now! or2stoptxt T&Cs
# Spam probability: 0.9775
# Actual label: spam
#
# Message: 08714712388 between 10am-7pm Cost 10p
# Spam probability: 0.6793
# Actual label: spam
#
# Message: +449071512431 URGENT! This is the 2nd attempt to contact U!U have WON £1250 CALL 09071512433 b4 050703 T&CsBCM4235WC1N3XX. callcost 150ppm mobilesvary. max£7. 50
# Spam probability: 0.9709
# Actual label: spam
#
# Message: You have WON a guaranteed £1000 cash or a £2000 prize. To claim yr prize call our customer service representative on 08714712394 between 10am-7pm
# Spam probability: 0.9972
# Actual label: spam
#
# Message: Hi. Customer Loyalty Offer:The NEW Nokia6650 Mobile from ONLY £10 at TXTAUCTION! Txt word: START to No: 81151 & get yours Now! 4T&Ctxt TC 150p/MTmsg
# Spam probability: 0.8325
# Actual label: spam
#
# Message: U are subscribed to the best Mobile Content Service in the UK for £3 per 10 days until you send STOP to 82324. Helpline 08706091795
# Spam probability: 0.9326
# Actual label: spam
#
# Message: You have an important customer service announcement from PREMIER.
# Spam probability: 0.8934
# Actual label: spam
#
# Message: Urgent Ur £500 guaranteed award is still unclaimed! Call 09066368327 NOW closingdate04/09/02 claimcode M39M51 £1.50pmmorefrommobile2Bremoved-MobyPOBox734LS27YF
# Spam probability: 0.6813
# Actual label: spam
#
# Message: UR awarded a City Break and could WIN a £200 Summer Shopping spree every WK. Txt STORE to 88039 . SkilGme. TsCs087147403231Winawk!Age16 £1.50perWKsub
# Spam probability: 0.9605
# Actual label: spam
#
# Message: You have an important customer service announcement from PREMIER. Call FREEPHONE 0800 542 0578 now!
# Spam probability: 0.9378
# Actual label: spam
#
# Message: 5 Free Top Polyphonic Tones call 087018728737, National Rate. Get a toppoly tune sent every week, just text SUBPOLY to 81618, £3 per pole. UnSub 08718727870.
# Spam probability: 0.9194
# Actual label: spam
#
# Message: Orange customer, you may now claim your FREE CAMERA PHONE upgrade for your loyalty. Call now on 0207 153 9996. Offer ends 14thMarch. T&C's apply. Opt-out availa
# Spam probability: 0.9736
# Actual label: spam
#
# Message: Last Chance! Claim ur £150 worth of discount vouchers today! Text SHOP to 85023 now! SavaMob, offers mobile! T Cs SavaMob POBOX84, M263UZ. £3.00 Sub. 16
# Spam probability: 0.9873
# Actual label: spam
#
# Message: FREE for 1st week! No1 Nokia tone 4 ur mobile every week just txt NOKIA to 8077 Get txting and tell ur mates. www.getzed.co.uk POBox 36504 W45WQ 16+ norm150p/tone
# Spam probability: 0.9921
# Actual label: spam
#
# Message: You have won a guaranteed £200 award or even £1000 cashto claim UR award call free on 08000407165 (18+) 2 stop getstop on 88222 PHP. RG21 4JX
# Spam probability: 0.9494
# Actual label: spam
#
# Message: Congratulations ur awarded either £500 of CD gift vouchers & Free entry 2 our £100 weekly draw txt MUSIC to 87066 TnCs www.Ldew.com1win150ppmx3age16
# Spam probability: 0.9944
# Actual label: spam
#
# Message: U were outbid by simonwatson5120 on the Shinco DVD Plyr. 2 bid again, visit sms. ac/smsrewards 2 end bid notifications, reply END OUT
# Spam probability: 0.5925
# Actual label: spam
#
# Message: SMSSERVICES. for yourinclusive text credits, pls goto www.comuk.net login= 3qxj9 unsubscribe with STOP, no extra charge. help 08702840625.COMUK. 220-CM2 9AE
# Spam probability: 0.9200
# Actual label: spam
#
# Message: 25p 4 alfie Moon's Children in need song on ur mob. Tell ur m8s. Txt Tone charity to 8007 for Nokias or Poly charity for polys: zed 08701417012 profit 2 charity.
# Spam probability: 0.9617
# Actual label: spam
#
# Message: U have a secret admirer. REVEAL who thinks U R So special. Call 09065174042. To opt out Reply REVEAL STOP. 1.50 per msg recd. Cust care 07821230901
# Spam probability: 0.9079
# Actual label: spam
#
# Message: Dear Voucher Holder, To claim this weeks offer, at you PC please go to http://www.e-tlp.co.uk/expressoffer Ts&Cs apply. To stop texts, txt STOP to 80062
# Spam probability: 0.9796
# Actual label: spam
#
# Message: Do you want 750 anytime any network mins 150 text and a NEW VIDEO phone for only five pounds per week call 08002888812 or reply for delivery tomorrow
# Spam probability: 0.8619
# Actual label: spam
#
# Message: We tried to contact you re our offer of New Video Phone 750 anytime any network mins HALF PRICE Rental camcorder call 08000930705 or reply for delivery Wed
# Spam probability: 0.9683
# Actual label: spam
#
# Message: Last chance 2 claim ur £150 worth of discount vouchers-Text YES to 85023 now!SavaMob-member offers mobile T Cs 08717898035. £3.00 Sub. 16 . Remove txt X or STOP
# Spam probability: 0.9731
# Actual label: spam
#
# Message: Urgent! call 09066350750 from your landline. Your complimentary 4* Ibiza Holiday or 10,000 cash await collection SAE T&Cs PO BOX 434 SK3 8WP 150 ppm 18+
# Spam probability: 0.9983
# Actual label: spam
#
# Message: Today's Offer! Claim ur £150 worth of discount vouchers! Text YES to 85023 now! SavaMob, member offers mobile! T Cs 08717898035. £3.00 Sub. 16 . Unsub reply X
# Spam probability: 0.9884
# Actual label: spam
#
# Message: Congratulations ur awarded either a yrs supply of CDs from Virgin Records or a Mystery Gift GUARANTEED Call 09061104283 Ts&Cs www.smsco.net £1.50pm approx 3mins
# Spam probability: 0.9555
# Actual label: spam
#
# Message: PRIVATE! Your 2003 Account Statement for 07808 XXXXXX shows 800 un-redeemed S. I. M. points. Call 08719899217 Identifier Code: 41685 Expires 07/11/04
# Spam probability: 0.9908
# Actual label: spam
#
# Message: What do U want for Xmas? How about 100 free text messages & a new video phone with half price line rental? Call free now on 0800 0721072 to find out more!
# Spam probability: 0.9141
# Actual label: spam
#
# Message: Shop till u Drop, IS IT YOU, either 10K, 5K, £500 Cash or £100 Travel voucher, Call now, 09064011000. NTT PO Box CR01327BT fixedline Cost 150ppm mobile vary
# Spam probability: 0.9629
# Actual label: spam
#
# Message: Sunshine Quiz Wkly Q! Win a top Sony DVD player if u know which country Liverpool played in mid week? Txt ansr to 82277. £1.50 SP:Tyrone
# Spam probability: 0.9702
# Actual label: spam
#
# Message: U have a secret admirer who is looking 2 make contact with U-find out who they R*reveal who thinks UR so special-call on 09058094565
# Spam probability: 0.8921
# Actual label: spam
#
# Message: U have a Secret Admirer who is looking 2 make contact with U-find out who they R*reveal who thinks UR so special-call on 09065171142-stopsms-08
# Spam probability: 0.8921
# Actual label: spam
#
# Message: Your free ringtone is waiting to be collected. Simply text the password "MIX" to 85069 to verify. Get Usher and Britney. FML, PO Box 5249, MK17 92H. 450Ppw 16
# Spam probability: 0.9493
# Actual label: spam
#
# Message: all the lastest from Stereophonics, Marley, Dizzee Racal, Libertines and The Strokes! Win Nookii games with Flirt!! Click TheMob WAP Bookmark or text WAP to 82468
# Spam probability: 0.6844
# Actual label: spam
#
# Message: January Male Sale! Hot Gay chat now cheaper, call 08709222922. National rate from 1.5p/min cheap to 7.8p/min peak! To stop texts call 08712460324 (10p/min)
# Spam probability: 0.9382
# Actual label: spam
#
# Message: money!!! you r a lucky winner ! 2 claim your prize text money 2 88600 over £1million to give away ! ppt150x3+normal text rate box403 w1t1jy
# Spam probability: 0.6830
# Actual label: spam
#
# Message: Dear Matthew please call 09063440451 from a landline, your complimentary 4*Lux Tenerife holiday or £1000 CASH await collection. ppm150 SAE T&Cs Box334 SK38XH.
# Spam probability: 0.9951
# Actual label: spam
#
# Message: Urgent! call 09061749602 from Landline. Your complimentary 4* Tenerife Holiday or £10,000 cash await collection SAE T&Cs BOX 528 HP20 1YF 150ppm 18+
# Spam probability: 0.9971
# Actual label: spam
#
# Message: Ur cash-balance is currently 500 pounds - to maximize ur cash-in now send GO to 86688 only 150p/msg. CC: 08718720201 PO BOX 114/14 TCR/W1
# Spam probability: 0.9791
# Actual label: spam
#
# Message: URGENT! We are trying to contact U. Todays draw shows that you have won a £800 prize GUARANTEED. Call 09050001808 from land line. Claim M95. Valid12hrs only
# Spam probability: 0.9970
# Actual label: spam
#
# Message: Congrats! 2 mobile 3G Videophones R yours. call 09063458130 now! videochat wid your mates, play java games, Dload polyPH music, noline rentl.
# Spam probability: 0.9198
# Actual label: spam
#
# Message: Please call our customer service representative on FREEPHONE 0808 145 4742 between 9am-11pm as you have WON a guaranteed £1000 cash or £5000 prize!
# Spam probability: 0.9939
# Actual label: spam
#
# Message: Panasonic & BluetoothHdset FREE. Nokia FREE. Motorola FREE & DoubleMins & DoubleTxt on Orange contract. Call MobileUpd8 on 08000839402 or call 2optout
# Spam probability: 0.8993
# Actual label: spam
#
# Message: FREE for 1st week! No1 Nokia tone 4 ur mob every week just txt NOKIA to 8007 Get txting and tell ur mates www.getzed.co.uk POBox 36504 W45WQ norm150p/tone 16+
# Spam probability: 0.9931
# Actual label: spam
#
# Message: 18 days to Euro2004 kickoff! U will be kept informed of all the latest news and results daily. Unsubscribe send GET EURO STOP to 83222.
# Spam probability: 0.8809
# Actual label: spam
#
# Message: EASTENDERS TV Quiz. What FLOWER does DOT compare herself to? D= VIOLET E= TULIP F= LILY txt D E or F to 84025 NOW 4 chance 2 WIN £100 Cash WKENT/150P16+
# Spam probability: 0.9417
# Actual label: spam
#
# Message: Someone U know has asked our dating service 2 contact you! Cant Guess who? CALL 09058091854 NOW all will be revealed. PO BOX385 M6 6WU
# Spam probability: 0.9245
# Actual label: spam
#
# Message: URGENT! We are trying to contact U. Todays draw shows that you have won a £800 prize GUARANTEED. Call 09050003091 from land line. Claim C52. Valid12hrs only
# Spam probability: 0.9970
# Actual label: spam
#
# Message: Dear U've been invited to XCHAT. This is our final attempt to contact u! Txt CHAT to 86688
# Spam probability: 0.8850
# Actual label: spam
#
# Message: You are awarded a SiPix Digital Camera! call 09061221061 from landline. Delivery within 28days. T Cs Box177. M221BP. 2yr warranty. 150ppm. 16 . p p£3.99
# Spam probability: 0.9900
# Actual label: spam
#
# Message: WIN URGENT! Your mobile number has been awarded with a £2000 prize GUARANTEED call 09061790121 from land line. claim 3030 valid 12hrs only 150ppm
# Spam probability: 0.9985
# Actual label: spam
#
# Message: Dear Subscriber ur draw 4 £100 gift voucher will b entered on receipt of a correct ans. When was Elvis Presleys Birthday? TXT answer to 80062
# Spam probability: 0.8320
# Actual label: spam
#
# Message: Message Important information for O2 user. Today is your lucky day! 2 find out why log onto http://www.urawinner.com there is a fantastic surprise awaiting you
# Spam probability: 0.9273
# Actual label: spam
#
# Message: 449050000301 You have won a £2,000 price! To claim, call 09050000301.
# Spam probability: 0.8105
# Actual label: spam
#
# Message: Do you want 750 anytime any network mins 150 text and a NEW video phone for only five pounds per week call 08000776320 now or reply for delivery Tomorrow
# Spam probability: 0.8619
# Actual label: spam
#
# Message: Ur HMV Quiz cash-balance is currently £500 - to maximize ur cash-in now send HMV1 to 86688 only 150p/msg
# Spam probability: 0.9239
# Actual label: spam
#
# Message: Thank you, winner notified by sms. Good Luck! No future marketing reply STOP to 84122 customer services 08450542832
# Spam probability: 0.8245
# Actual label: spam
#
# Message: Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive entry question(std txt rate)T&C's apply 08452810075over18's
# Spam probability: 0.9517
# Actual label: spam
#
# Message: Got what it takes 2 take part in the WRC Rally in Oz? U can with Lucozade Energy! Text RALLY LE to 61200 (25p), see packs or lucozade.co.uk/wrc & itcould be u!
# Spam probability: 0.7475
# Actual label: spam
#
# Message: Sex up ur mobile with a FREE sexy pic of Jordan! Just text BABE to 88600. Then every wk get a sexy celeb! PocketBabe.co.uk 4 more pics. 16 £3/wk 087016248
# Spam probability: 0.6654
# Actual label: spam
#
# Message: You have 1 new voicemail. Please call 08719181503
# Spam probability: 0.5835
# Actual label: spam
#
# Message: WIN a year supply of CDs 4 a store of ur choice worth £500 & enter our £100 Weekly draw txt MUSIC to 87066 Ts&Cs www.Ldew.com.subs16+1win150ppmx3
# Spam probability: 0.9461
# Actual label: spam
#
# Message: As a SIM subscriber, you are selected to receive a Bonus! Get it delivered to your door, Txt the word OK to No: 88600 to claim. 150p/msg, EXP. 30Apr
# Spam probability: 0.8929
# Actual label: spam
#
# Message: You have 1 new voicemail. Please call 08719181513.
# Spam probability: 0.5835
# Actual label: spam
#
# Message: No. 1 Nokia Tone 4 ur mob every week! Just txt NOK to 87021. 1st Tone FREE ! so get txtin now and tell ur friends. 150p/tone. 16 reply HL 4info
# Spam probability: 0.9827
# Actual label: spam
#
# Message: You are a winner U have been specially selected 2 receive £1000 cash or a 4* holiday (flights inc) speak to a live operator 2 claim 0871277810810
# Spam probability: 0.9861
# Actual label: spam
#
# Message: FREE entry into our £250 weekly comp just send the word ENTER to 84128 NOW. 18 T&C www.textcomp.com cust care 08712405020.
# Spam probability: 0.8708
# Actual label: spam
#
# Message: Please CALL 08712402779 immediately as there is an urgent message waiting for you
# Spam probability: 0.8181
# Actual label: spam
#
# Message: network operator. The service is free. For T & C's visit 80488.biz
# Spam probability: 0.8232
# Actual label: spam
#
# Message: Enjoy the jamster videosound gold club with your credits for 2 new videosounds+2 logos+musicnews! get more fun from jamster.co.uk! 16+only Help? call: 09701213186
# Spam probability: 0.5189
# Actual label: spam
#
# Message: Get 3 Lions England tone, reply lionm 4 mono or lionp 4 poly. 4 more go 2 www.ringtones.co.uk, the original n best. Tones 3GBP network operator rates apply
# Spam probability: 0.9804
# Actual label: spam
#
# Message: Win the newest “Harry Potter and the Order of the Phoenix (Book 5) reply HARRY, answer 5 questions - chance to be the first among readers!
# Spam probability: 0.8260
# Actual label: spam
#
# Message: FREE2DAY sexy St George's Day pic of Jordan!Txt PIC to 89080 dont miss out, then every wk a saucy celeb!4 more pics c PocketBabe.co.uk 0870241182716 £3/wk
# Spam probability: 0.8117
# Actual label: spam
#
# Message: HOT LIVE FANTASIES call now 08707509020 Just 20p per min NTT Ltd, PO Box 1327 Croydon CR9 5WB 0870..k
# Spam probability: 0.9889
# Actual label: spam
#
# Message: Bears Pic Nick, and Tom, Pete and ... Dick. In fact, all types try gay chat with photo upload call 08718730666 (10p/min). 2 stop texts call 08712460324
# Spam probability: 0.6710
# Actual label: spam
#
# Message: 500 New Mobiles from 2004, MUST GO! Txt: NOKIA to No: 89545 & collect yours today!From ONLY £1 www.4-tc.biz 2optout 087187262701.50gbp/mtmsg18 TXTAUCTION
# Spam probability: 0.9468
# Actual label: spam
#
# Message: Double Mins & Double Txt & 1/2 price Linerental on Latest Orange Bluetooth mobiles. Call MobileUpd8 for the very latest offers. 08000839402 or call2optout/LF56
# Spam probability: 0.9592
# Actual label: spam
#
# Message: No. 1 Nokia Tone 4 ur mob every week! Just txt NOK to 87021. 1st Tone FREE ! so get txtin now and tell ur friends. 150p/tone. 16 reply HL 4info
# Spam probability: 0.9827
# Actual label: spam
#
# Message: URGENT, IMPORTANT INFORMATION FOR O2 USER. TODAY IS YOUR LUCKY DAY! 2 FIND OUT WHY LOG ONTO HTTP://WWW.URAWINNER.COM THERE IS A FANTASTIC SURPRISE AWAITING FOR YOU
# Spam probability: 0.9516
# Actual label: spam
#
# Message: Dear U've been invited to XCHAT. This is our final attempt to contact u! Txt CHAT to 86688 150p/MsgrcvdHG/Suite342/2Lands/Row/W1J6HL LDN 18 yrs
# Spam probability: 0.9398
# Actual label: spam
#
# Message: Congratulations ur awarded either £500 of CD gift vouchers & Free entry 2 our £100 weekly draw txt MUSIC to 87066 TnCs www.Ldew.com 1 win150ppmx3age16
# Spam probability: 0.9939
# Actual label: spam
#
# Message: Free 1st week entry 2 TEXTPOD 4 a chance 2 win 40GB iPod or £250 cash every wk. Txt POD to 84128 Ts&Cs www.textpod.net custcare 08712405020.
# Spam probability: 0.9811
# Actual label: spam
#
# Message: As a registered optin subscriber ur draw 4 £100 gift voucher will be entered on receipt of a correct ans to 80062 Whats No1 in the BBC charts
# Spam probability: 0.8669
# Actual label: spam
#
# Message: Summers finally here! Fancy a chat or flirt with sexy singles in yr area? To get MATCHED up just reply SUMMER now. Free 2 Join. OptOut txt STOP Help08714742804
# Spam probability: 0.8875
# Actual label: spam
#
# Message: Bought one ringtone and now getting texts costing 3 pound offering more tones etc
# Spam probability: 0.5910
# Actual label: spam
#
# Message: 09066362231 URGENT! Your mobile No 07xxxxxxxxx won a £2,000 bonus caller prize on 02/06/03! this is the 2nd attempt to reach YOU! call 09066362231 ASAP!
# Spam probability: 0.9744
# Actual label: spam
#
# Message: YOU 07801543489 are guaranteed the latests Nokia Phone, a 40GB iPod MP3 player or a £500 prize! Txt word:COLLECT to No:83355! TC-LLC NY-USA 150p/Mt msgrcvd18+
# Spam probability: 0.9567
# Actual label: spam
#
# Message: Your account has been credited with 500 FREE Text Messages. To activate, just txt the word: CREDIT to No: 80488 T&Cs www.80488.biz
# Spam probability: 0.8725
# Actual label: spam
#
# Message: HOT LIVE FANTASIES call now 08707509020 Just 20p per min NTT Ltd, PO Box 1327 Croydon CR9 5WB 0870 is a national rate call
# Spam probability: 0.9946
# Actual label: spam
#
# Message: Our brand new mobile music service is now live. The free music player will arrive shortly. Just install on your phone to browse content from the top artists.
# Spam probability: 0.8445
# Actual label: spam
#
# Message: URGENT! Your Mobile No was awarded a £2,000 Bonus Caller Prize on 1/08/03! This is our 2nd attempt to contact YOU! Call 0871-4719-523 BOX95QU BT National Rate
# Spam probability: 0.9940
# Actual label: spam
#
# Message: You have won a Nokia 7250i. This is what you get when you win our FREE auction. To take part send Nokia to 86021 now. HG/Suite342/2Lands Row/W1JHL 16+
# Spam probability: 0.9588
# Actual label: spam
#
# Message: Hello from Orange. For 1 month's free access to games, news and sport, plus 10 free texts and 20 photo messages, reply YES. Terms apply: www.orange.co.uk/ow
# Spam probability: 0.7908
# Actual label: spam
#
# Message: Ur cash-balance is currently 500 pounds - to maximize ur cash-in now send GO to 86688 only 150p/msg. CC 08718720201 HG/Suite342/2Lands Row/W1J6HL
# Spam probability: 0.9713
# Actual label: spam
#
# Message: SMS AUCTION - A BRAND NEW Nokia 7250 is up 4 auction today! Auction is FREE 2 join & take part! Txt NOKIA to 86021 now! HG/Suite342/2Lands Row/W1J6HL
# Spam probability: 0.9525
# Actual label: spam
#
# Message: PRIVATE! Your 2003 Account Statement for shows 800 un-redeemed S. I. M. points. Call 08719899230 Identifier Code: 41685 Expires 07/11/04
# Spam probability: 0.9929
# Actual label: spam
#
# Message: As a Registered Subscriber yr draw 4 a £100 gift voucher will b entered on receipt of a correct ans. When are the next olympics. Txt ans to 80062
# Spam probability: 0.9082
# Actual label: spam
#
# Message: URGENT! Your Mobile number has been awarded with a £2000 prize GUARANTEED. Call 09061790121 from land line. Claim 3030. Valid 12hrs only 150ppm
# Spam probability: 0.9983
# Actual label: spam
#
# Message: RT-KIng Pro Video Club>> Need help? info@ringtoneking.co.uk or call 08701237397 You must be 16+ Club credits redeemable at www.ringtoneking.co.uk! Enjoy!
# Spam probability: 0.6002
# Actual label: spam
#
# Message: U have a secret admirer who is looking 2 make contact with U-find out who they R*reveal who thinks UR so special-call on 09058094599
# Spam probability: 0.8921
# Actual label: spam
#
# Message: You have been selected to stay in 1 of 250 top British hotels - FOR NOTHING! Holiday Worth £350! To Claim, Call London 02072069400. Bx 526, SW73SS
# Spam probability: 0.8810
# Actual label: spam
#
# Message: Eerie Nokia tones 4u, rply TONE TITLE to 8007 eg TONE DRACULA to 8007 Titles: GHOST, ADDAMSFA, MUNSTERS, EXORCIST, TWILIGHT www.getzed.co.uk POBox36504W45WQ 150p
# Spam probability: 0.9247
# Actual label: spam
#
# Message: For ur chance to win a £250 cash every wk TXT: ACTION to 80608. T's&C's www.movietrivia.tv custcare 08712405022, 1x150p/wk
# Spam probability: 0.9743
# Actual label: spam
#
# Message: RGENT! This is the 2nd attempt to contact U!U have WON £1250 CALL 09071512433 b4 050703 T&CsBCM4235WC1N3XX. callcost 150ppm mobilesvary. max£7. 50
# Spam probability: 0.9541
# Actual label: spam
#
# Message: URGENT! We are trying to contact U. Todays draw shows that you have won a £800 prize GUARANTEED. Call 09050001295 from land line. Claim A21. Valid 12hrs only
# Spam probability: 0.9979
# Actual label: spam
#
# Message: todays vodafone numbers ending with 0089(my last four digits) are selected to received a £350 award. If your number matches please call 09063442151 to claim your £350 award
# Spam probability: 0.9584
# Actual label: spam
#
# Message: Free Top ringtone -sub to weekly ringtone-get 1st week free-send SUBPOLY to 81618-?3 per week-stop sms-08718727870
# Spam probability: 0.9570
# Actual label: spam
#
# Message: Sunshine Quiz Wkly Q! Win a top Sony DVD player if u know which country the Algarve is in? Txt ansr to 82277. £1.50 SP:Tyrone
# Spam probability: 0.9661
# Actual label: spam
#
# Message: Free msg. Sorry, a service you ordered from 81303 could not be delivered as you do not have sufficient credit. Please top up to receive the service.
# Spam probability: 0.7098
# Actual label: spam
#
# Message: Hard LIVE 121 chat just 60p/min. Choose your girl and connect LIVE. Call 09094646899 now! Cheap Chat UK's biggest live service. VU BCM1896WC1N3XX
# Spam probability: 0.9030
# Actual label: spam
#
# Message: WOW! The Boys R Back. TAKE THAT 2007 UK Tour. Win VIP Tickets & pre-book with VIP Club. Txt CLUB to 81303. Trackmarque Ltd info@vipclub4u.
# Spam probability: 0.5999
# Actual label: spam
#
# Message: Hi, this is Mandy Sullivan calling from HOTMIX FM...you are chosen to receive £5000.00 in our Easter Prize draw.....Please telephone 09041940223 to claim before 29/03/05 or your prize will be transferred to someone else....
# Spam probability: 0.7750
# Actual label: spam
#
# Message: UR GOING 2 BAHAMAS! CallFREEFONE 08081560665 and speak to a live operator to claim either Bahamas cruise of£2000 CASH 18+only. To opt out txt X to 07786200117
# Spam probability: 0.8983
# Actual label: spam
#
# Message: Someone has conacted our dating service and entered your phone because they fancy you!To find out who it is call from landline 09111030116. PoBox12n146tf15
# Spam probability: 0.9198
# Actual label: spam
#
# Message: Hi 07734396839 IBH Customer Loyalty Offer: The NEW NOKIA6600 Mobile from ONLY £10 at TXTAUCTION!Txt word:START to No:81151 & get Yours Now!4T&
# Spam probability: 0.8607
# Actual label: spam
#
# Message: SMS AUCTION You have won a Nokia 7250i. This is what you get when you win our FREE auction. To take part send Nokia to 86021 now. HG/Suite342/2Lands Row/W1JHL 16+
# Spam probability: 0.9650
# Actual label: spam
#
# Message: Call FREEPHONE 0800 542 0578 now!
# Spam probability: 0.5939
# Actual label: spam
#
# Message: Buy Space Invaders 4 a chance 2 win orig Arcade Game console. Press 0 for Games Arcade (std WAP charge) See o2.co.uk/games 4 Terms + settings. No purchase
# Spam probability: 0.9122
# Actual label: spam
#
# Message: Loan for any purpose £500 - £75,000. Homeowners + Tenants welcome. Have you been previously refused? We can still help. Call Free 0800 1956669 or text back 'help'
# Spam probability: 0.8616
# Actual label: spam
#
# Message: BIG BROTHER ALERT! The computer has selected u for 10k cash or #150 voucher. Call 09064018838. NTT PO Box CRO1327 18+ BT Landline Cost 150ppm mobiles vary
# Spam probability: 0.9667
# Actual label: spam
#
# Message: WIN: We have a winner! Mr. T. Foley won an iPod! More exciting prizes soon, so keep an eye on ur mobile or visit www.win-82050.co.uk
# Spam probability: 0.8084
# Actual label: spam
#
# Message: Todays Voda numbers ending 1225 are selected to receive a £50award. If you have a match please call 08712300220 quoting claim code 3100 standard rates app
# Spam probability: 0.9878
# Actual label: spam
#
# Message: Hottest pics straight to your phone!! See me getting Wet and Wanting, just for you xx Text PICS to 89555 now! txt costs 150p textoperator g696ga 18 XxX
# Spam probability: 0.5062
# Actual label: spam
#
# Message: Hack Chat. Get backdoor entry into 121 chat rooms at a fraction of the cost. Reply NEO69 or call 09050280520, to subscribe 25p pm. DPS, Bcm box 8027 Ldn, wc1n3xx
# Spam probability: 0.7247
# Actual label: spam
#
# Message: FREE NOKIA Or Motorola with upto 12mths 1/2price linerental, 500 FREE x-net mins&100txt/mth FREE B'tooth*. Call Mobileupd8 on 08001950382 or call 2optout/D3WV
# Spam probability: 0.9085
# Actual label: spam
#
# Message: This is the 2nd time we have tried 2 contact u. U have won the 750 Pound prize. 2 claim is easy, call 08718726970 NOW! Only 10p per min. BT-national-rate
# Spam probability: 0.9852
# Actual label: spam
#
# Message: You have WON a guaranteed £1000 cash or a £2000 prize.To claim yr prize call our customer service representative on
# Spam probability: 0.9929
# Actual label: spam
#
# Message: HMV BONUS SPECIAL 500 pounds of genuine HMV vouchers to be won. Just answer 4 easy questions. Play Now! Send HMV to 86688 More info:www.100percent-real.com
# Spam probability: 0.9214
# Actual label: spam
#
# Message: U have a secret admirer who is looking 2 make contact with U-find out who they R*reveal who thinks UR so special-call on 09058094594
# Spam probability: 0.8921
# Actual label: spam
#
# Message: Dear 0776xxxxxxx U've been invited to XCHAT. This is our final attempt to contact u! Txt CHAT to 86688 150p/MsgrcvdHG/Suite342/2Lands/Row/W1J6HL LDN 18yrs
# Spam probability: 0.9284
# Actual label: spam
#
# Message: Urgent! Please call 09061743811 from landline. Your ABTA complimentary 4* Tenerife Holiday or £5000 cash await collection SAE T&Cs Box 326 CW25WX 150ppm
# Spam probability: 0.9974
# Actual label: spam
#
# Message: Free entry in 2 a weekly comp for a chance to win an ipod. Txt POD to 80182 to get entry (std txt rate) T&C's apply 08452810073 for details 18+
# Spam probability: 0.9923
# Actual label: spam
#
# Message: New TEXTBUDDY Chat 2 horny guys in ur area 4 just 25p Free 2 receive Search postcode or at gaytextbuddy.com. TXT ONE name to 89693. 08715500022 rpl Stop 2 cnl
# Spam probability: 0.7739
# Actual label: spam
#
# Message: Call from 08702490080 - tells u 2 call 09066358152 to claim £5000 prize. U have 2 enter all ur mobile & personal details @ the prompts. Careful!
# Spam probability: 0.7622
# Actual label: spam
#
# Message: Free 1st week entry 2 TEXTPOD 4 a chance 2 win 40GB iPod or £250 cash every wk. Txt VPOD to 81303 Ts&Cs www.textpod.net custcare 08712405020.
# Spam probability: 0.9768
# Actual label: spam
#
# Message: WELL DONE! Your 4* Costa Del Sol Holiday or £5000 await collection. Call 09050090044 Now toClaim. SAE, TCs, POBox334, Stockport, SK38xh, Cost£1.50/pm, Max10mins
# Spam probability: 0.9941
# Actual label: spam
#
# Message: it to 80488. Your 500 free text messages are valid until 31 December 2005.
# Spam probability: 0.7257
# Actual label: spam
#
# Message: You have won a guaranteed £200 award or even £1000 cashto claim UR award call free on 08000407165 (18+) 2 stop getstop on 88222 PHP
# Spam probability: 0.9494
# Actual label: spam
#
# Message: Reply to win £100 weekly! Where will the 2006 FIFA World Cup be held? Send STOP to 87239 to end service
# Spam probability: 0.7911
# Actual label: spam
#
# Message: Urgent! Please call 09061743810 from landline. Your ABTA complimentary 4* Tenerife Holiday or #5000 cash await collection SAE T&Cs Box 326 CW25WX 150 ppm
# Spam probability: 0.9974
# Actual label: spam
#
# Message: Free tones Hope you enjoyed your new content. text stop to 61610 to unsubscribe. help:08712400602450p Provided by tones2you.co.uk
# Spam probability: 0.9016
# Actual label: spam
#
# Message: Great News! Call FREEFONE 08006344447 to claim your guaranteed £1000 CASH or £2000 gift. Speak to a live operator NOW!
# Spam probability: 0.9372
# Actual label: spam
#
# Message: U can WIN £100 of Music Gift Vouchers every week starting NOW Txt the word DRAW to 87066 TsCs www.ldew.com SkillGame,1Winaweek, age16.150ppermessSubscription
# Spam probability: 0.9431
# Actual label: spam
#
# Message: 4mths half price Orange line rental & latest camera phones 4 FREE. Had your phone 11mths ? Call MobilesDirect free on 08000938767 to update now! or2stoptxt
# Spam probability: 0.9711
# Actual label: spam
#
# Message: Call 09094100151 to use ur mins! Calls cast 10p/min (mob vary). Service provided by AOM, just GBP5/month. AOM Box61,M60 1ER until u stop. Ages 18+ only!
# Spam probability: 0.7494
# Actual label: spam
#
# Message: URGENT! Your mobile No *********** WON a £2,000 Bonus Caller Prize on 02/06/03! This is the 2nd attempt to reach YOU! Call 09066362220 ASAP! BOX97N7QP, 150ppm
# Spam probability: 0.9811
# Actual label: spam
#
# Message: Eerie Nokia tones 4u, rply TONE TITLE to 8007 eg TONE DRACULA to 8007 Titles: GHOST, ADDAMSFA, MUNSTERS, EXORCIST, TWILIGHT www.getzed.co.uk POBox36504W45WQ 150p
# Spam probability: 0.9247
# Actual label: spam
#
# Message: FreeMsg: Claim ur 250 SMS messages-Text OK to 84025 now!Use web2mobile 2 ur mates etc. Join Txt250.com for 1.50p/wk. T&C BOX139, LA32WU. 16 . Remove txtX or stop
# Spam probability: 0.8563
# Actual label: spam
#
# Message: Well done ENGLAND! Get the official poly ringtone or colour flag on yer mobile! text TONE or FLAG to 84199 NOW! Opt-out txt ENG STOP. Box39822 W111WX £1.50
# Spam probability: 0.9644
# Actual label: spam
#
# Message: Final Chance! Claim ur £150 worth of discount vouchers today! Text YES to 85023 now! SavaMob, member offers mobile! T Cs SavaMob POBOX84, M263UZ. £3.00 Subs 16
# Spam probability: 0.9915
# Actual label: spam
#
# Message: PRIVATE! Your 2004 Account Statement for 07742676969 shows 786 unredeemed Bonus Points. To claim call 08719180248 Identifier Code: 45239 Expires
# Spam probability: 0.9966
# Actual label: spam
#
# Message: SMS SERVICES. for your inclusive text credits, pls goto www.comuk.net login= ***** unsubscribe with STOP. no extra charge. help:08700469649. PO BOX420. IP4 5WE
# Spam probability: 0.9593
# Actual label: spam
#
# Message: FREE2DAY sexy St George's Day pic of Jordan!Txt PIC to 89080 dont miss out, then every wk a saucy celeb!4 more pics c PocketBabe.co.uk 0870241182716 £3/wk
# Spam probability: 0.8117
# Actual label: spam
#
# Message: You are a winner you have been specially selected to receive £1000 cash or a £2000 award. Speak to a live operator to claim call 087123002209am-7pm. Cost 10p
# Spam probability: 0.9924
# Actual label: spam
#
# Message: Sunshine Hols. To claim ur med holiday send a stamped self address envelope to Drinks on Us UK, PO Box 113, Bray, Wicklow, Eire. Quiz Starts Saturday! Unsub Stop
# Spam probability: 0.9532
# ...
# Spam probability: 0.9814
# Actual label: spam
#
# Message: Todays Vodafone numbers ending with 4882 are selected to a receive a £350 award. If your number matches call 09064019014 to receive your £350 award.
# Spam probability: 0.9269
# Actual label: spam
#
# Message: Want the latest Video handset? 750 anytime any network mins? Half price line rental? Reply or call 08000930705 for delivery tomorrow
# Spam probability: 0.9644
# Actual label: spam
#
# Message: ou are guaranteed the latest Nokia Phone, a 40GB iPod MP3 player or a £500 prize! Txt word: COLLECT to No: 83355! IBHltd LdnW15H 150p/Mtmsgrcvd18
# Spam probability: 0.9777
# Actual label: spam
#
# Message: * FREE* POLYPHONIC RINGTONE Text SUPER to 87131 to get your FREE POLY TONE of the week now! 16 SN PoBox202 NR31 7ZS subscription 450pw
# Spam probability: 0.8747
# Actual label: spam
#
# Message: Warner Village 83118 C Colin Farrell in SWAT this wkend @Warner Village & get 1 free med. Popcorn!Just show msg+ticket@kiosk.Valid 4-7/12. C t&c @kiosk. Reply SONY 4 mre film offers
# Spam probability: 0.5152
# Actual label: spam
#
# Message: This is the 2nd time we have tried 2 contact u. U have won the 750 Pound prize. 2 claim is easy, call 08712101358 NOW! Only 10p per min. BT-national-rate
# Spam probability: 0.9852
# Actual label: spam
#
# Message: Got what it takes 2 take part in the WRC Rally in Oz? U can with Lucozade Energy! Text RALLY LE to 61200 (25p), see packs or lucozade.co.uk/wrc & itcould be u!
# Spam probability: 0.7475
# Actual label: spam
#
# Message: Great News! Call FREEFONE 08006344447 to claim your guaranteed £1000 CASH or £2000 gift. Speak to a live operator NOW!
# Spam probability: 0.9372
# Actual label: spam
#
# Message: Welcome to Select, an O2 service with added benefits. You can now call our specially trained advisors FREE from your mobile by dialling 402.
# Spam probability: 0.6777
# Actual label: spam
#
# Message: URGENT! We are trying to contact U. Todays draw shows that you have won a £2000 prize GUARANTEED. Call 09058094507 from land line. Claim 3030. Valid 12hrs only
# Spam probability: 0.9979
# Actual label: spam
#
# Message: goldviking (29/M) is inviting you to be his friend. Reply YES-762 or NO-762 See him: www.SMS.ac/u/goldviking STOP? Send STOP FRND to 62468
# Spam probability: 0.6901
# Actual label: spam
#
# Message: Phony £350 award - Todays Voda numbers ending XXXX are selected to receive a £350 award. If you have a match please call 08712300220 quoting claim code 3100 standard rates app
# Spam probability: 0.9873
# Actual label: spam
#
# Message: CDs 4u: Congratulations ur awarded £500 of CD gift vouchers or £125 gift guaranteed & Freeentry 2 £100 wkly draw xt MUSIC to 87066 TnCs www.ldew.com1win150ppmx3age16
# Spam probability: 0.9831
# Actual label: spam
#
# Message: You have WON a guaranteed £1000 cash or a £2000 prize. To claim yr prize call our customer service representative on 08714712412 between 10am-7pm Cost 10p
# Spam probability: 0.9977
# Actual label: spam
#
# Message: Dear 0776xxxxxxx U've been invited to XCHAT. This is our final attempt to contact u! Txt CHAT to 86688 150p/MsgrcvdHG/Suite342/2Lands/Row/W1J6HL LDN 18yrs
# Spam probability: 0.9284
# Actual label: spam
#
# Message: Ur cash-balance is currently 500 pounds - to maximize ur cash-in now send GO to 86688 only 150p/meg. CC: 08718720201 HG/Suite342/2lands Row/W1j6HL
# Spam probability: 0.9531
# Actual label: spam
#
# Message: PRIVATE! Your 2003 Account Statement for shows 800 un-redeemed S.I.M. points. Call 08715203685 Identifier Code:4xx26 Expires 13/10/04
# Spam probability: 0.9812
# Actual label: spam
#
# Message: I'd like to tell you my deepest darkest fantasies. Call me 09094646631 just 60p/min. To stop texts call 08712460324 (nat rate)
# Spam probability: 0.7835
# Actual label: spam
#
# Message: You won't believe it but it's true. It's Incredible Txts! Reply G now to learn truly amazing things that will blow your mind. From O2FWD only 18p/txt
# Spam probability: 0.6640
# Actual label: spam
#
# Message: Natalie (20/F) is inviting you to be her friend. Reply YES-165 or NO-165 See her: www.SMS.ac/u/natalie2k9 STOP? Send STOP FRND to 62468
# Spam probability: 0.6901
# Actual label: spam
#
# Message: Jamster! To get your free wallpaper text HEART to 88888 now! T&C apply. 16 only. Need Help? Call 08701213186.
# Spam probability: 0.6183
# Actual label: spam
#
# Message: Double Mins & Double Txt & 1/2 price Linerental on Latest Orange Bluetooth mobiles. Call MobileUpd8 for the very latest offers. 08000839402 or call2optout/LF56
# Spam probability: 0.9592
# Actual label: spam
#
# Message: Free video camera phones with Half Price line rental for 12 mths and 500 cross ntwk mins 100 txts. Call MobileUpd8 08001950382 or Call2OptOut/674
# Spam probability: 0.9849
# Actual label: spam
#
# Message: 83039 62735=£450 UK Break AccommodationVouchers terms & conditions apply. 2 claim you mustprovide your claim number which is 15541
# Spam probability: 0.8642
# Actual label: spam
#
# Message: 5p 4 alfie Moon's Children in need song on ur mob. Tell ur m8s. Txt Tone charity to 8007 for Nokias or Poly charity for polys: zed 08701417012 profit 2 charity.
# Spam probability: 0.9617
# Actual label: spam
#
# Message: WIN a £200 Shopping spree every WEEK Starting NOW. 2 play text STORE to 88039. SkilGme. TsCs08714740323 1Winawk! age16 £1.50perweeksub.
# Spam probability: 0.7129
# Actual label: spam
#
# Message: This is the 2nd attempt to contract U, you have won this weeks top prize of either £1000 cash or £200 prize. Just call 09066361921
# Spam probability: 0.9164
# Actual label: spam
#
# Message: Do you want a New Nokia 3510i colour phone DeliveredTomorrow? With 300 free minutes to any mobile + 100 free texts + Free Camcorder reply or call 08000930705.
# Spam probability: 0.9780
# Actual label: spam
#
# Message: This msg is for your mobile content order It has been resent as previous attempt failed due to network error Queries to customersqueries@netvision.uk.com
# Spam probability: 0.5839
# Actual label: spam
#
# Message: A Boy loved a gal. He propsd bt she didnt mind. He gv lv lttrs, Bt her frnds threw thm. Again d boy decided 2 aproach d gal , dt time a truck was speeding towards d gal. Wn it was about 2 hit d girl,d boy ran like hell n saved her. She asked 'hw cn u run so fast?' D boy replied "Boost is d secret of my energy" n instantly d girl shouted "our energy" n Thy lived happily 2gthr drinking boost evrydy Moral of d story:- I hv free msgs:D;): gud ni8
# Spam probability: 0.5083
# Actual label: ham
#
# Message: You have 1 new message. Please call 08715205273
# Spam probability: 0.5121
# Actual label: spam
#
# Message: December only! Had your mobile 11mths+? You are entitled to update to the latest colour camera mobile for Free! Call The Mobile Update VCo FREE on 08002986906
# Spam probability: 0.9525
# Actual label: spam
#
# Message: Get 3 Lions England tone, reply lionm 4 mono or lionp 4 poly. 4 more go 2 www.ringtones.co.uk, the original n best. Tones 3GBP network operator rates apply.
# Spam probability: 0.9804
# Actual label: spam
#
# Message: PRIVATE! Your 2003 Account Statement for 078
# Spam probability: 0.8496
# Actual label: spam
#
# Message: YOU VE WON! Your 4* Costa Del Sol Holiday or £5000 await collection. Call 09050090044 Now toClaim. SAE, TC s, POBox334, Stockport, SK38xh, Cost£1.50/pm, Max10mins
# Spam probability: 0.9969
# Actual label: spam
#
# Message: FREE for 1st week! No1 Nokia tone 4 ur mobile every week just txt NOKIA to 8077 Get txting and tell ur mates. www.getzed.co.uk POBox 36504 W45WQ 16+ norm150p/tone
# Spam probability: 0.9921
# Actual label: spam
#
# Message: Get your garden ready for summer with a FREE selection of summer bulbs and seeds worth £33:50 only with The Scotsman this Saturday. To stop go2 notxt.co.uk
# Spam probability: 0.7762
# Actual label: spam
#
# Message: Congrats 2 mobile 3G Videophones R yours. call 09063458130 now! videochat wid ur mates, play java games, Dload polypH music, noline rentl. bx420. ip4. 5we. 150p
# Spam probability: 0.9508
# Actual label: spam
#
# Message: SMS AUCTION - A BRAND NEW Nokia 7250 is up 4 auction today! Auction is FREE 2 join & take part! Txt NOKIA to 86021 now!
# Spam probability: 0.9127
# Actual label: spam
#
# Message: ree entry in 2 a weekly comp for a chance to win an ipod. Txt POD to 80182 to get entry (std txt rate) T&C's apply 08452810073 for details 18+
# Spam probability: 0.9899
# Actual label: spam
#
# Message: Our records indicate u maybe entitled to 5000 pounds in compensation for the Accident you had. To claim 4 free reply with CLAIM to this msg. 2 stop txt STOP
# Spam probability: 0.9502
# Actual label: spam
#
# Message: Spook up your mob with a Halloween collection of a logo & pic message plus a free eerie tone, txt CARD SPOOK to 8007 zed 08701417012150p per logo/pic
# Spam probability: 0.9735
# Actual label: spam
#
# Message: Call Germany for only 1 pence per minute! Call from a fixed line via access number 0844 861 85 85. No prepayment. Direct access! www.telediscount.co.uk
# Spam probability: 0.7840
# Actual label: spam
#
# Message: YOU VE WON! Your 4* Costa Del Sol Holiday or £5000 await collection. Call 09050090044 Now toClaim. SAE, TC s, POBox334, Stockport, SK38xh, Cost£1.50/pm, Max10mins
# Spam probability: 0.9969
# Actual label: spam
#
# Message: Had your mobile 11mths ? Update for FREE to Oranges latest colour camera mobiles & unlimited weekend calls. Call Mobile Upd8 on freefone 08000839402 or 2StopTxt
# Spam probability: 0.9662
# Actual label: spam
#
# Message: Natalja (25/F) is inviting you to be her friend. Reply YES-440 or NO-440 See her: www.SMS.ac/u/nat27081980 STOP? Send STOP FRND to 62468
# Spam probability: 0.8221
# Actual label: spam
#
# Message: PRIVATE! Your 2003 Account Statement for <fone no> shows 800 un-redeemed S. I. M. points. Call 08715203656 Identifier Code: 42049 Expires 26/10/04
# Spam probability: 0.9887
# Actual label: spam
#
# Message: YOU ARE CHOSEN TO RECEIVE A £350 AWARD! Pls call claim number 09066364311 to collect your award which you are selected to receive as a valued mobile customer.
# Spam probability: 0.9779
# Actual label: spam
#
# Message: Someonone you know is trying to contact you via our dating service! To find out who it could be call from your mobile or landline 09064015307 BOX334SK38ch
# Spam probability: 0.8591
# Actual label: spam
#
# Message: Urgent! Please call 09061213237 from a landline. £5000 cash or a 4* holiday await collection. T &Cs SAE PO Box 177 M227XY. 16+
# Spam probability: 0.9928
# Actual label: spam
#
# Message: If you don't, your prize will go to another customer. T&C at www.t-c.biz 18+ 150p/min Polo Ltd Suite 373 London W1J 6HL Please call back if busy
# Spam probability: 0.8314
# Actual label: spam
#
# Message: URGENT! Your Mobile number has been awarded with a £2000 prize GUARANTEED. Call 09061790126 from land line. Claim 3030. Valid 12hrs only 150ppm
# Spam probability: 0.9983
# Actual label: spam
#
# Message: URGENT! You have won a 1 week FREE membership in our £100,000 Prize Jackpot! Txt the word: CLAIM to No: 81010 T&C www.dbuk.net LCCLTD POBOX 4403LDNW1A7RW18
# Spam probability: 0.9611
# Actual label: spam
#
# Message: Urgent! Please call 09061213237 from landline. £5000 cash or a luxury 4* Canary Islands Holiday await collection. T&Cs SAE PO Box 177. M227XY. 150ppm. 16+
# Spam probability: 0.9944
# Actual label: spam
#
# Message: XMAS iscoming & ur awarded either £500 CD gift vouchers & free entry 2 r £100 weekly draw txt MUSIC to 87066 TnC www.Ldew.com1win150ppmx3age16subscription
# Spam probability: 0.9901
# Actual label: spam
#
# Message: Get the official ENGLAND poly ringtone or colour flag on yer mobile for tonights game! Text TONE or FLAG to 84199. Optout txt ENG STOP Box39822 W111WX £1.50
# Spam probability: 0.9653
# Actual label: spam
#
# Message: u r subscribed 2 TEXTCOMP 250 wkly comp. 1st wk?s free question follows, subsequent wks charged@150p/msg.2 unsubscribe txt STOP 2 84128,custcare 08712405020
# Spam probability: 0.9334
# Actual label: spam
#
# Message: Call 09095350301 and send our girls into erotic ecstacy. Just 60p/min. To stop texts call 08712460324 (nat rate)
# Spam probability: 0.8186
# Actual label: spam
#
# Message: Camera - You are awarded a SiPix Digital Camera! call 09061221066 fromm landline. Delivery within 28 days.
# Spam probability: 0.9690
# Actual label: spam
#
# Message: A £400 XMAS REWARD IS WAITING FOR YOU! Our computer has randomly picked you from our loyal mobile customers to receive a £400 reward. Just call 09066380611
# Spam probability: 0.7955
# Actual label: spam
#
# Message: IMPORTANT MESSAGE. This is a final contact attempt. You have important messages waiting out our customer claims dept. Expires 13/4/04. Call 08717507382 NOW!
# Spam probability: 0.7392
# Actual label: spam
#
# Message: The current leading bid is 151. To pause this auction send OUT. Customer Care: 08718726270
# Spam probability: 0.5136
# Actual label: spam
#
# Message: Free entry to the gr8prizes wkly comp 4 a chance to win the latest Nokia 8800, PSP or £250 cash every wk.TXT GREAT to 80878 http//www.gr8prizes.com 08715705022
# Spam probability: 0.9531
# Actual label: spam
#
# Message: You have won a guaranteed 32000 award or maybe even £1000 cash to claim ur award call free on 0800 ..... (18+). Its a legitimat efreefone number wat do u think???
# Spam probability: 0.7906
# Actual label: spam
#
# Message: December only! Had your mobile 11mths+? You are entitled to update to the latest colour camera mobile for Free! Call The Mobile Update Co FREE on 08002986906
# Spam probability: 0.9448
# Actual label: spam
#
# Message: Txt: CALL to No: 86888 & claim your reward of 3 hours talk time to use from your phone now! Subscribe6GBP/mnth inc 3hrs 16 stop?txtStop www.gamb.tv
# Spam probability: 0.8164
# Actual label: spam
#
# Message: http//tms. widelive.com/index. wml?id=820554ad0a1705572711&first=true¡C C Ringtone¡
# Spam probability: 0.5680
# Actual label: spam
#
# Message: Get your garden ready for summer with a FREE selection of summer bulbs and seeds worth £33:50 only with The Scotsman this Saturday. To stop go2 notxt.co.uk
# Spam probability: 0.7762
# Actual label: spam
#
# Message: URGENT! Last weekend's draw shows that you have won £1000 cash or a Spanish holiday! CALL NOW 09050000332 to claim. T&C: RSTM, SW7 3SS. 150ppm
# Spam probability: 0.9754
# Actual label: spam
#
# Message: URGENT We are trying to contact you Last weekends draw shows u have won a £1000 prize GUARANTEED Call 09064017295 Claim code K52 Valid 12hrs 150p pm
# Spam probability: 0.9954
# Actual label: spam
#
# Message: 2p per min to call Germany 08448350055 from your BT line. Just 2p per min. Check PlanetTalkInstant.com for info & T's & C's. Text stop to opt out
# Spam probability: 0.8641
# Actual label: spam
#
# Message: SMS SERVICES. for your inclusive text credits, pls goto www.comuk.net login= 3qxj9 unsubscribe with STOP, no extra charge. help 08702840625.COMUK. 220-CM2 9AE
# Spam probability: 0.9574
# Actual label: spam
#
# Message: PRIVATE! Your 2003 Account Statement for 07808247860 shows 800 un-redeemed S. I. M. points. Call 08719899229 Identifier Code: 40411 Expires 06/11/04
# Spam probability: 0.9929
# Actual label: spam
#
# Message: You are awarded a SiPix Digital Camera! call 09061221061 from landline. Delivery within 28days. T Cs Box177. M221BP. 2yr warranty. 150ppm. 16 . p p£3.99
# Spam probability: 0.9900
# Actual label: spam
#
# Message: PRIVATE! Your 2003 Account Statement for shows 800 un-redeemed S.I.M. points. Call 08718738001 Identifier Code: 49557 Expires 26/11/04
# Spam probability: 0.9914
# Actual label: spam
#
# Message: Want explicit SEX in 30 secs? Ring 02073162414 now! Costs 20p/min Gsex POBOX 2667 WC1N 3XX
# Spam probability: 0.8019
# Actual label: spam
#
# Message: Had your contract mobile 11 Mnths? Latest Motorola, Nokia etc. all FREE! Double Mins & Text on Orange tariffs. TEXT YES for callback, no to remove from records.
# Spam probability: 0.9706
# Actual label: spam
#
# Message: This is the 2nd time we have tried 2 contact u. U have won the £750 Pound prize. 2 claim is easy, call 087187272008 NOW1! Only 10p per minute. BT-national-rate.
# Spam probability: 0.9808
# Actual label: spam
#
# === SUMMARY ===
# Total messages: 5572
# Spam messages: 620
# Ham messages: 4952
# Spam rate: 11.13%
# Results saved to adv
# Found 620 spam messages out of 5572 total messages
# Spam rate: 11.13%
